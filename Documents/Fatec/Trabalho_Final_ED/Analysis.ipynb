# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dados = pd.read_csv('vgsales.csv')
dados
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# ...

# %%
dados.head(20) ## os 10 jogos mais vendidos de todos os tempos.
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %% [markdown]
# ### VENDAS POR GENERO
# > Como podemos observar no grafico abaixo, Nos Ultimos 31 anos(1985-2016), o genero de jogo que mais se vendeu foram os jogos de ação, dominando aproximadamente 20% da faixa do mercado de vendas.

# %%
ce = dados['Genre'].value_counts()
a = ce.plot(kind='pie', autopct='%.2f', figsize=(20,20))

# %%
year = dados['Year'].value_counts()
a = year.head(20).plot(kind='bar', figsize=(20,20), grid=False,title='Vendas Por Ano',fontsize=(12))

# %%
publisher= dados['Publisher'].value_counts().sort_values()
publisher.tail(10).plot(kind='barh', figsize=(20,20), grid=False, title='Vendas por Publisher', fontsize=(12))

# %%
plgr= pd.crosstab(dados['Platform'],dados['Genre']).sort_values('Platform')
plgr['Sports'].sort_values().tail(15).plot(kind='barh', figsize=(10,10), stacked= True)
plt.title('Os consoles mais vendidos nos ultimos 25 anos.')
plt.show()

# %%
dados.query('Platform=="PS2"')['Genre'].value_counts().sort_values().plot(kind='barh', figsize=(13,7))
plt.title("OS GENEROS MAIS VENDIDOS NO CONSOLE MAIS VENDIDO.")
plt.show()

# %%
def pesquisaVideoGame(nome):
    if nome == 'XONE':
        nome='XOne'
    elif nome=='XBOX ONE':
        nome='XOne'
    elif nome=='Xbox 360' or nome=='XBOX360' or nome=='xbox 360':
        nome='X360'
    elif nome=='Xbox' or nome=='xbox' or nome=='x-box':
        nome='XB'
    query='Platform=="x"'
    query= query.replace('x',nome.upper())
    dados.query(query)['Genre'].value_counts().plot(kind='barh')
    plt.title('Vendas por Gênero no Console')
    plt.xlabel('Quantidade de vendas')
    plt.ylabel('Gênero')
    plt.show()

# %%
#essa funcao so pode ser usada com os nomes inseridos no proprio csv
# 'PCFX', 'GG', '3DO', 'TG16', 'WS', 'NG', 'SCD', 'DC', 'GEN', 'SAT', 'PSV', 'WiiU', '2600', 'XOne', 'GC', 'SNES', 'N64', '3DS'
#'NES', 'GB', 'XB', 'PC', 'PS4', 'PSP', 'GBA', 'PS', 'DS', 'Wii', 'PS3', 'X360', 'PS2'
def pesquisaGeneroConsoleTodos(nome):
    if nome == 'XONE':
        nome='XOne'
    elif nome=='XBOX ONE':
        nome='XOne'
    elif nome=='Xbox 360' or nome=='XBOX360' or nome=='xbox 360':
        nome='X360'
    elif nome=='Xbox' or nome=='xbox' or nome=='x-box':
        nome='XB'
    query='Platform=="x"'
    query= query.replace('x',nome)
    data = slrg.query(query)
    data = data.T
    a = data[nome].sort_values().drop('Global_Sales')
    chart = a.plot(kind='pie', autopct='%.2f', figsize=(20,20))
    plt.title(nome)
    plt.legend(['JP_Sales','NA_Sales','EU_Sales','Other_Sales'])
    plt.show()

# %%
pesquisaVideoGame("sat")

# %%
test= pd.groupby
#test.plot(kind='barh', figsize=(10,10), stacked= True)
test=dados.groupby('Platform')['Platform','JP_Sales','NA_Sales','EU_Sales','Other_Sales','Global_Sales']

# %%
test.head()
# Out:
#       Platform  JP_Sales  NA_Sales  EU_Sales  Other_Sales  Global_Sales
# 0          Wii      3.77     41.49     29.02         8.46         82.74
# 1          NES      6.81     29.08      3.58         0.77         40.24
# 2          Wii      3.79     15.85     12.88         3.31         35.82
# 3          Wii      3.28     15.75     11.01         2.96         33.00
# 4           GB     10.22     11.27      8.89         1.00         31.37
# 5           GB      4.22     23.20      2.26         0.58         30.26
# 6           DS      6.50     11.38      9.23         2.90         30.01
# 7          Wii      2.93     14.03      9.20         2.85         29.02
# 8          Wii      4.70     14.59      7.06         2.26         28.62
# 9          NES      0.28     26.93      0.63         0.47         28.31
# 10          DS      1.93      9.07     11.00         2.75         24.76
# 11          DS      4.13      9.81      7.57         1.92         23.42
# ...

# %%
jp=dados.query('Platform=="Wii"')['JP_Sales'].sum()
eu=dados.query('Platform=="Wii"')['EU_Sales'].sum()
na=dados.query('Platform=="Wii"')['NA_Sales'].sum()
other=dados.query('Platform=="Wii"')['Other_Sales'].sum()
globin=dados.query('Platform=="Wii"')['Global_Sales'].sum()

# %%
print('jp',jp)
print('eu',eu)
print('na',na)
print('other',other)
print('globin',globin)


soma=jp+eu+na+other
print('SOMA',soma)
# Out:
# jp 69.35000000000001
# eu 268.38
# na 507.71
# other 80.61
# globin 926.71
# SOMA 926.0500000000001

# %%
#cross= pd.crosstab(dados['Platform'],dados['Global_Sales']).sort_values('Platform')
dados['Platform']

tabelinha=pd.crosstab(dados['Platform'],dados['Global_Sales'])
tabelinha

slrg=dados.groupby('Platform')['Platform','JP_Sales','NA_Sales','EU_Sales','Other_Sales','Global_Sales'].sum()
slrg
# Out:
#           JP_Sales  NA_Sales  EU_Sales  Other_Sales  Global_Sales
# Platform
# 2600          0.00     90.60      5.47         0.91         97.08
# 3DO           0.10      0.00      0.00         0.00          0.10
# 3DS          97.35     78.87     58.52        12.63        247.46
# DC            8.56      5.43      1.69         0.27         15.97
# DS          175.57    390.71    194.65        60.53        822.49
# GB           85.12    114.32     47.82         8.20        255.45
# GBA          47.33    187.54     75.25         7.73        318.50
# GC           21.58    133.46     38.71         5.18        199.36
# GEN           2.67     19.27      5.52         0.89         28.36
# GG            0.04      0.00      0.00         0.00          0.04
# N64          34.22    139.02     41.06         4.38        218.88
# NES          98.65    125.94     21.15         5.31        251.07
# NG            1.44      0.00      0.00         0.00          1.44
# ...

# %%
ce = slrg['Global_Sales'].sort_values().tail(10)
a = ce.plot(kind='pie', autopct='%.2f', figsize=(20,20))

# %%
#essa funcao so pode ser usada com os nomes inseridos no proprio csv
# 'PCFX', 'GG', '3DO', 'TG16', 'WS', 'NG', 'SCD', 'DC', 'GEN', 'SAT', 'PSV', 'WiiU', '2600', 'XOne', 'GC', 'SNES', 'N64', '3DS'
#'NES', 'GB', 'XB', 'PC', 'PS4', 'PSP', 'GBA', 'PS', 'DS', 'Wii', 'PS3', 'X360', 'PS2'
def pesquisaConsoleRegiao(nome):
    if nome == 'XONE':
        nome='XOne'
    elif nome=='XBOX ONE':
        nome='XOne'
    elif nome=='Xbox 360' or nome=='XBOX360' or nome=='xbox 360':
        nome='X360'
    elif nome=='Xbox' or nome=='xbox' or nome=='x-box':
        nome='XB'
    query='Platform=="x"'
    query= query.replace('x',nome)
    data = slrg.query(query)
    data = data.T
    a = data[nome].sort_values().drop('Global_Sales')
    chart = a.plot(kind='pie', autopct='%.2f', figsize=(20,20))
    plt.title("GRAFICOS DE CONSOLE/REGIAO :"+nome)
    plt.legend(['JP_Sales','NA_Sales','EU_Sales','Other_Sales'])
    plt.show()

# %%
lista = []
for index,value in ce.iteritems():
    lista.append(index)
for i in range(0,len(lista)):
    pesquisaConsoleRegiao(lista[i])
